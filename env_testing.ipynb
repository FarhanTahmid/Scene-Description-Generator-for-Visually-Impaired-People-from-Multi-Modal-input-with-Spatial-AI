# %%
import torch

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
else:
    print("No GPU available. Training will run on CPU.")
# Out:
# GPU: NVIDIA GeForce GTX 1650 SUPER is available.

# %%
import tensorflow as tf
 
# Check if GPU is available
print("GPU is available:", tf.config.list_physical_devices('GPU'))
 
# Check if TensorFlow is using GPU for computation
print("TensorFlow is using GPU:", tf.test.is_built_with_cuda())
 
# Check the GPU devices available
print("Available GPU devices:")
for device in tf.config.list_physical_devices('GPU'):
    print("Device name:", device.name)
# Out:
# GPU is available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow is using GPU: True
# Available GPU devices:
# Device name: /physical_device:GPU:0
